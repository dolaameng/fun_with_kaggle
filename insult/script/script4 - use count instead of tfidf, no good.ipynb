# %%
import numpy as np
import scipy as sp
import pylab as pl
from sklearn.feature_extraction import text
from sklearn import feature_selection
from sklearn import svm
from sklearn import linear_model
from sklearn import neighbors
from sklearn import naive_bayes
from sklearn import metrics
from sklearn import cross_validation
from sklearn import grid_search
from sklearn import ensemble
from sklearn import decomposition
import csv, codecs, re, unicodedata
import simplenlp
from nltk import corpus
from nltk import tokenize
import nltk
from nltk import collocations
from nltk import stem
from time import time

# %%
CHAT_WORDS = set([w.lower() for w in corpus.nps_chat.words()])
POS_KEY_WORDS = set(['maggot', 'pussy','dumb','bitch', 'momscreen','suffer','nazi',
     'shit','troll','rapist','bastard','hoe','buddy','idiot','dick','cuz','tard','breath','stupidity',
     'black','moron','racist', 'asshole','ass','shut','shitshut','complete','screen',
     'motherfucker','mom','crawl','fag','cunt','sound','knock','retard','plain',
     'coward','loser','lil','stupid','dirty','turd','cock','suck', 'fuck'])
STOP_WORDS = set([w.lower() for w in corpus.stopwords.words('english')])
CHAT_WO_STOP_WORDS = CHAT_WORDS - STOP_WORDS | set(['u','you','ur', 'are', 're'])

# %%
## CONSTANTS and CONTROLS
TEST_RATIO = 0
SELECT_CHI2 = 1 # 0 or negative values to turn it off
FEATURE_EXTRACTION = 'raw' # possbile values 'raw' (non), 'pca', 'ica', 'l1-svc' (linear svc with l1 penalty)

# %%
## function to load unicode CSV
def read_csv_columns(csv_file, columns, header = True):
    reader = csv.reader(codecs.open(csv_file, 'r', 'latin-1'), delimiter=',')
    if header:
        next(reader)
    data = []
    for row in reader:
        fields = []
        for c in columns:
            txt = re.sub(r'^"|"$','',row[c]).decode('unicode-escape')
            try:
                txt = txt.decode('unicode-escape')
            except: pass
            unicodedata.normalize('NFKD', txt).encode('ascii', 'ignore')
            fields.append(simplenlp.preprocess_text(txt))
        data.append(fields)
    return np.array(data)

def write_output(classifier, X, output_path = '../data/output.csv'):
    probas = classifier.predict_proba(X)
    with open(output_path, 'w') as f:
        f.write('Insult,\n')
        for i in xrange(probas.shape[0]):
            f.write(str(probas[i,1]))
            f.write(',\n')

# %%
## load train and test data
train_data = read_csv_columns('../data/train.csv', columns = (0, 2))
test_data = read_csv_columns('../data/test_with_solutions.csv', columns= (0, 2))

# %%
X = train_data[:, 1]
y = np.array(train_data[:, 0], dtype='uint8')
## 1. split the data into training and test
## train_X, test_X, train_y, test_y = cross_validation.train_test_split(X, y, test_size = TEST_RATIO, random_state = 0)
## 2. directly use the test.csv as test data
train_X, train_y = X, y
test_X, test_y = test_data[:, 1], np.array(test_data[:, 0], dtype='uint8')
## overfitting
#train_X, train_y = np.hstack((train_X, test_X)), np.hstack((train_y, test_y))

# %%
######### nltk analysis ###########
train_pos_tweets, train_neg_tweets = train_X[train_y == 1], train_X[train_y == 0]
test_pos_tweets, test_neg_tweets = test_X[test_y == 1], test_X[test_y == 0]
## Bigram for positive tweets
train_pos_words = [w.lower() for w in tokenize.wordpunct_tokenize(' '.join(train_pos_tweets))]
word_filter = lambda w: len(w) < 3 or w in STOP_WORDS
pos_bicollocator = collocations.BigramCollocationFinder.from_words(train_pos_words)
pos_bicollocator.apply_word_filter(word_filter)
POS_BI_COLLACATIONS = pos_bicollocator.nbest(nltk.metrics.BigramAssocMeasures.likelihood_ratio, 100)
stemmer = stem.PorterStemmer()

# %%
## find synonyms of a word
def synonyms(word):
    return [lemma.name for syn in corpus.wordnet.synsets(word) for lemma in syn.lemmas]

def my_tokenizer(txt):
    ## assert s.islower()
    ########### preprocessing  ############
    ## remove @name tag name - dont remove it, use it!
    #txt = re.compile(r'@\w+').sub('', txt)
    ## remove topics susch as #1
    txt = re.compile(r'(\A|\s)#[\w\d]+').sub("",txt)
    ## condense 3 or more than 3 letters into 1, e.g. hhhheeeello to hello
    txt = re.compile(r'(\w)\1{2,}').sub(r'\1', txt)
    feats = []
    ############ features based on raw text #############
    
    ############ features based on lower text ###########
    txt = txt.lower()
    nametags = re.findall(r'@\w+', txt)
    if nametags:
        feats += ['@NameTags']
    htmltags = re.findall(r'html', txt)
    if htmltags:
        feats += ['@HtmlTags']
    if any([w in txt for w in ['u', 'you', 'you are', 'ur']]):
        feats += ['@YouAre']
    ## has positive words
    if any([w in txt for w in POS_KEY_WORDS]):
        feats += ['@HasPositive']
    ## postive bi_collocations
    #for pair in POS_BI_COLLACATIONS:
    #    if all([w in txt for w in pair]):
    #        feats.append(pair)
    ############ features based on bag of words #########
    words = tokenize.wordpunct_tokenize(txt)
    ## stem words
    words = map(lambda w: stemmer.stem(w), words)
    ## bag of words
    #feats += filter(lambda t: t.isalpha() and t in CHAT_WORDS, words)
    feats += words
    ## has positive words
    ##if any([w in POS_KEY_WORDS for w in words]):
    ##    feats += ['@HasPositive']
    feats += [tuple(words[i:i+2]) for i in xrange(len(words)-1)]
    ## words after you, u, ur you're
    strict_words = filter(lambda w: w.isalpha() and w in CHAT_WO_STOP_WORDS, words)
    feats += [tuple(strict_words[i:i+2])
                for (i,w) in enumerate(strict_words) if w in ('you', 'u', 'ur')]
    feats += [tuple(strict_words[i:i+3])
                for (i,w) in enumerate(strict_words) if w in ('you', 'u', 'ur')]
    ## biwords of strict words
    feats += [(strict_words[i], strict_words[i+1]) for i in xrange(len(strict_words)-1)]
    ## synonyms of strict words
    #for sw in strict_words:
    #    if sw in POS_KEY_WORDS:
    #        feats += synonyms(w)
    for w in words:
        try:
            pos = corpus.wordnet.synsets(w)[0].pos
            if pos in ('n', 'a', 'v'):
                feats += [(w, pos)]
        except: pass
    return feats

## building features on training data
#tfidf_vectorizer = text.TfidfVectorizer(charset = 'latin-1', lowercase=False, 
#                                            sublinear_tf=True, tokenizer = my_tokenizer,#vocabulary = CHAT_WORDS,
#                                            max_df=1.0)#, norm = 'l1')
tfidf_vectorizer = text.CountVectorizer(charset='latin-1', lowercase=False,
                                        tokenizer=my_tokenizer)
print 'extracting tfidf from training set...'
t0 = time()
train_X = tfidf_vectorizer.fit_transform(train_X)
print 'done in %0.2fs' % (time() - t0)
print 'shape of training data', train_X.shape
# Out:
# extracting tfidf from training set...
# done in 23.96s
# shape of training data (3947, 27221)

# %%
## add extra features to tfidf
'@HasPositive' in tfidf_vectorizer.get_feature_names()
#print filter(lambda f: f[0]=='you', tfidf_vectorizer.get_feature_names())
# Out:
# True

# %%
## extract features from test data using same feature set
print 'extracting tfidf from testing set...'
t0 = time()
test_X = tfidf_vectorizer.transform(test_X)
print 'done in %0.2fs' % (time() - t0)
print 'shape of testing data', test_X.shape
# Out:
# extracting tfidf from testing set...
# done in 6.73s
# shape of testing data (2647, 27221)

# %%
## optionally do feature selection based on chi2
if SELECT_CHI2 > 0:
    n_selected_features = int(train_X.shape[1] * SELECT_CHI2)
    print 'Extracting %d best features by a chi-squred test' % n_selected_features
    t0 = time()
    ch2 = feature_selection.SelectKBest(feature_selection.chi2, k = n_selected_features)
    train_X = ch2.fit_transform(train_X, train_y)
    test_X = ch2.transform(test_X)
    print 'done in %0.2fs' % (time() - t0)
# Out:
# Extracting 27221 best features by a chi-squred test
# done in 0.14s

# %%
## optionally do feature extraction based on PCA or ICA
if FEATURE_EXTRACTION == 'raw':
    pass
elif FEATURE_EXTRACTION == 'pca':
    t0 = time()
    pca = decomposition.PCA(n_components=100)
    train_X = sp.sparse.coo_matrix(pca.fit_transform(train_X.todense()))
    test_X = sp.sparse.coo_matrix(pca.transform(test_X.todense()))
    print 'pca done in %0.3f' % (time() - t0)
elif FEATURE_EXTRACTION == 'ica':
    t0 = time()
    ica = decomposition.FastICA(n_components = 100)
    train_X = sp.sparse.coo_matrix(ica.fit_transform(train_X.todense()))
    test_X = sp.sparse.coo_matrix(ica.transform(test_X.todense()))
    print 'ica done in %0.3f' % (time() - t0)
elif FEATURE_EXTRACTION == 'l1-svc':
    t0 = time()
    l1svc = svm.LinearSVC(C = 1, penalty = 'l1', dual = False)
    l1svc.fit(train_X, train_y)
    train_X = l1svc.transform(train_X)
    test_X = l1svc.transform(test_X)
    print 'l1-svc feature selection done in %0.3f' % (time() - t0)
else:
    raise RuntimeError('unknown feature extraction method')

# %%
## define feature names from tfidf vectorizer
tfidf_feature_names = tfidf_vectorizer.get_feature_names()
print train_X.shape, test_X.shape
# Out:
# (3947, 27221) (2647, 27221)

# %%
## benchmark classifiers
def benchmark(clf):
    print 76 * '_'
    print 'training: '
    print clf
    t0 = time()
    clf.fit(train_X, train_y)
    print 'training time: %0.2f' % (time() - t0)
    
    t0 = time()
    if hasattr(clf, 'predict_proba'):
        try:
            pred_probas = clf.predict_proba(test_X)[:,1]
        except:
            pred_probas = None
    else:
        pred_probas = None
    pred = clf.predict(test_X)
    print 'test time: %0.2f' % (time() - t0)
    
    print 'confusion matrix:'
    print metrics.confusion_matrix(test_y, pred)
    
    print 'classification rate:'
    print np.mean(test_y == pred) * 100., '%'
    
    if pred_probas is not None:
        fpr, tpr, thresholds = metrics.roc_curve(test_y, pred_probas)
        auc_area = metrics.auc(fpr, tpr)
        print 'AUC for test: ', auc_area
        print 'ROC plot'
        pl.figure()
        pl.plot(fpr, tpr, 'b-')
    
    misclassified_indices = (test_y != pred)
    misclassified = zip(test_data[misclassified_indices], test_y[misclassified_indices])
    return misclassified

# %%
## test SVC
#svc_classifier = svm.SVC(kernel = 'linear', C = 10, gamma = 0.01,  tol=0.001, probability = True) # for tfidf l1 norm
svc_classifier = svm.SVC(kernel = 'linear', C = 1, gamma = 0.01,  tol=0.001, probability = True) # for tfidf l2 norm
#svc_classifier = svm.SVC(kernel = 'rbf', C = 10, gamma = 0.01,  tol=0.0001, probability = True)
misclassified = benchmark(svc_classifier)
# Out:
# ____________________________________________________________________________
# training:
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0, degree=3, gamma=0.01,
#   kernel=linear, probability=True, shrinking=True, tol=0.001,
#   verbose=False)
# training time: 9.91
# test time: 1.97
# confusion matrix:
# [[1743  211]
#  [ 506  187]]
# classification rate:
# 72.912731394 %
# AUC for test:  0.755141708059
# ROC plot

# %%
filter(lambda case: case[1] == 1, misclassified)
# Out:
# [(array([u'1',
#        u"To engage in an intelligent debate with you is like debating to a retarded person.  It's useless.  It looks like you're bent on disregarding the efforts of the government."],
#       dtype='<U13166'),
#   1),
#  (array([u'1', u'GO SUCK_YOU DADDYS_COCK_OBAMA LOVING LIBERAL_FAGGOT'],
#       dtype='<U13166'),
#   1),
#  (array([u'1',
#        u'flushres: Thanks caveman! I appreciate your Neanderthal mentality. You are welcome and good night...'],
#       dtype='<U13166'),
#   1),
#  (array([u'1',
#        u'Tell the veterans who did serve and prefer Romney to "go fuck themselves", why don\'t you? Oh wait, leftists  have been doing that for 40 years already.'],
#       dtype='<U13166'),
#   1),
#  (array([u'1',
#        u"Bigger than the Chicago Tribune and the Boston Globe?  Are you HIGH????   I've never even SEEN the daily caller, but I've bought the Tribune and read the Globe.  What else you got?  And by the way, your blog isn't legitimate.  It's a fucking blog.  A website.  I don't think that truly qualifies, no offense Raw.  But even YOU guys don't really count and you know it.  IF they don't want to give them a press pass there really isn't much that they can do to force the White House's hand.  If they give them a pass it's because they don't feel threatened and WANT him to keep up the bullshit to SHOW the country just what these people's true colors are.  Obama and pals ARE NOT playing the race card and never have, no matter how many times the right wing assholes keep repeating that bullshit.  But these people keep painting themselves into a corner of backwards-assed white power racist uncivilized and uninspiring troglodytes."],
#       dtype='<U13166'),
#   1),
#  (array([u'1', u'In your world of delusion of course.'],
#       dtype='<U13166'),
#   1),
#  (array([u'1',
#        u'I think Dirty Harry said it best. You are nothing but dog shit to me. Alot of things can happen to dog shit. It can be stepped on or dry up and blow away into the wind. So Russell, just beware of where the dog shits you.'],
#       dtype='<U13166'),
#   1),
#  (array([u'1', u"Us whites don't like coloured people."],
#       dtype='<U13166'),
#   1),
#  (array([u'1',
#        u'I know, horrid man, not taking a bundle of something fishy from Karchner. Are you actually as daft as you sound or are you putting it on ?'],
#       dtype='<U13166'),
#   1),
#  (array([u'1',
#        u"I'm a little fed up with you also. I usually just ignore your childish petulant posts.  You don\u2019t add much to the discussion any more."],
#       dtype='<U13166'),
#   1),
#  (array([u'1',
#        u'look, douchey,  how about i holster my cock in your mouth  hmmmmm?  like i said,  FOX NEWS is number one for a reason.. deal with it  and im sure the closer we get to november more and more people will see how much this dickwad in chief has been fucking up this great country.  Nothing I  say is going to sink in your thick bubble head.  If its not comming from the left, then your libtard brain says its lies... so you are helpless'],
#       dtype='<U13166'),
#   1),
#  (array([u'1',
#        u'@imjustsaying....: you got that right afro-american negro & we don\'t have respect for negro\'s who is still a "PU-CEE" to the clans from the south, so they make up an excuse to destroy one another & can\'t face the klans to get revenge.'],
#       dtype='<U13166'),
#   1),
#  (array([u'1',
#        u"Look who's calling the kettle black!  Egyptian soldiers have killed some.  Shaken down many others, Sinai Arabs have raped women, shaken them down, and even held some for ransom.  And you dare to impugn Israel?  You hypocritical bastard!"],
#       dtype='<U13166'),
#   1),
#  (array([u'1',
#        u
'],
#       dtype='<U13166'),
#   1),
#  (array([u'1',
#        u'we have been sinking under Krugmans and his ilk\'s platforms, for 45 YEARS... What proof do you need? Nobel prize?lol They also gave the "peace" prize to Obama who has now committed us to more wars then BUSH! The credit down grade happened because of our DEFICIT you TARD! Get your facts str8! racist baiting is old and tired.  The libs are the racists thinking that the judiciary has the power to grant minorities of color their freedom, when they get freedom from their CREATOR! You are a loon, a big racist libtard loon.'],
#       dtype='<U13166'),
#   1),
#  (array([u'1',
#        u'The easy part about Walker pissing me off is he arbitrily takes away a bargained for right. Then sits back while people like you, who know nothing about unions, do his dirty work for him. Why  enjoy being a pawn?'],
#       dtype='<U13166'),
#   1),
#  (array([u'1',
#        u'Another inferior leftist with no substance. Is that all you got?...."the car thief?"....sure sign you\'re losing. But then again inferior, leftists like you never address the facts of the issue....that\'s why you\'re inferior.'],
#       dtype='<U13166'),
#   1),
#  (array([u'1',
#        u'Is that why Obama has borrowed more money as president in 3 years than any other sitting president in US history?  You are delusional.'],
#       dtype='<U13166'),
#   1),
#  (array([u'1',
#        u"and I thought Dem's put up their presidential kneepad after Clinton left town.......  Guess not....so tell us.....u spit or swallow?"],
#       dtype='<U13166'),
#   1),
#  (array([u'1',
#        u"He didn't do anything to take away guns, even from buffoons like you!"],
#       dtype='<U13166'),
#   1),
#  (array([u'1',
#        u'You are a poor excuse for a human and one of the reasons our country is going down the toilet!!!!!'],
#       dtype='<U13166'),
#   1),
#  (array([u'1',
#        u'I\'m so tired of some people cramming their religion into other people\'s faces and being so noisy about it. I thought you were supposed to pray in closets. The first commandment should have been "Don\'t be a dick."'],
#       dtype='<U13166'),
#   1),
#  (array([u'1',
#        u'No, people have a right to speak, no matter how stupid they are.'],
#       dtype='<U13166'),
#   1),
#  (array([u'1',
#        u"Go use google simpleton, that's how the word is spelled.  You dense democrat!"],
#       dtype='<U13166'),
#   1)]

# %%
## test naive bayesian bernoulli
nb_bernoulli_classifier = naive_bayes.BernoulliNB(alpha = 0.3, fit_prior=True)# for tfidf l2 norm
#nb_bernoulli_classifier = naive_bayes.BernoulliNB(alpha = 0.3, fit_prior=True) # for tfidf l1 norm
misclassified = benchmark(nb_bernoulli_classifier)
#negative_features_indices = np.argsort(nb_bernoulli_classifier.feature_log_prob_[0,:])[-30:]
#negative_features = [tfidf_feature_names[i] for i in negative_features_indices]
#print 'negative features...'
#print negative_features
#positive_features_indices = np.argsort(nb_bernoulli_classifier.feature_log_prob_[1,:])[-50:]
#positive_features = [tfidf_feature_names[i] for i in positive_features_indices]
#print 'positive features...'
#print positive_features
# Out:
# ____________________________________________________________________________
# training:
# BernoulliNB(alpha=0.3, binarize=0.0, fit_prior=True)
# training time: 0.01
# test time: 0.02
# confusion matrix:
# [[1622  332]
#  [ 159  534]]
# classification rate:
# 81.4506989044 %
# AUC for test:
#  0.873701187928
# ROC plot

# %%
### classification by voting ####
class BiVotingClassifier:
    def __init__(self, model1, model2):
        self.model1 = model1
        self.model2 = model2
    def fit(self, X, y):
        self.model1.fit(X, y)
        self.model2.fit(X, y)
    def predict(self, X):
        proba = self.predict_proba(X)
        return np.argmax(proba, axis = 1)
    def predict_proba(self, X):
        proba1 = self.model1.predict_proba(X)
        proba2 = self.model2.predict_proba(X)
        n_samples, n_labels = proba1.shape
        assert n_labels == 2
        proba = np.zeros((n_samples, n_labels))
        for i in xrange(n_samples):
            proba[i, 0] = max(proba1[i, 0], proba2[i, 0])
            proba[i, 1] = max(proba1[i, 1], proba2[i, 1])
            proba[i, ] /= sum(proba[i, ])
            """
            if np.max(proba1[i,:]) > np.max(proba2[i,:]):
                proba[i, :] = proba1[i, :]
            else:
                proba[i, :] = proba2[i, :]
            """
        return proba
    
#bivoting = BiVotingClassifier(svm.SVC(kernel = 'rbf', C = 10, gamma = 0.01,  tol=0.0001, probability = True), 
bivoting = BiVotingClassifier(svm.SVC(kernel = 'linear', C = 1, gamma = 0.01,  tol=0.0001, probability = True), # for l2 norm
#bivoting = BiVotingClassifier(svm.SVC(kernel = 'linear', C = 10, gamma = 0.01,  tol=0.0001, probability = True), # for l1 norm
                                naive_bayes.BernoulliNB(alpha = 0.3, fit_prior=True))
misclassified = benchmark(bivoting)
# Out:
# ____________________________________________________________________________
# training:
# <__main__.BiVotingClassifier instance at 0x15520e200>
# training time: 10.37
# test time: 2.03
# confusion matrix:
# [[1681  273]
#  [ 175  518]]
# classification rate:
# 83.0751794484 %
# AUC for test:  0.8780855787
# ROC plot

# %%
write_output(bivoting, test_X)
print 'writing done...'
# Out:
# writing done...

# %%
## test SGD with Elastic Net penalty
sgdc_classifier = linear_model.SGDClassifier(alpha = 0.0001, n_iter = 200, penalty = 'l2')
misclassified = benchmark(sgdc_classifier)
# Out:
# ____________________________________________________________________________
# training:
# SGDClassifier(alpha=0.0001, class_weight=None, epsilon=0.1, eta0=0.0,
#        fit_intercept=True, learning_rate=optimal, loss=hinge, n_iter=200,
#        n_jobs=1, penalty=l2, power_t=0.5, rho=0.85, seed=0, shuffle=False,
#        verbose=0, warm_start=False)
# training time: 0.08
# test time: 0.00
# confusion matrix:
# [[1795  159]
#  [ 274  419]]
# classification rate:
# 83.641858708 %

# %%
## test ensemble random trees
forest_classifier = ensemble.RandomForestClassifier(n_estimators=60, n_jobs = -1)
train_X_sparse, test_X_sparse = train_X, test_X
train_X, test_X = train_X.todense(), test_X.todense()
misclassified = benchmark(forest_classifier)
train_X, test_X = train_X_sparse, test_X_sparse
# Out:
# ____________________________________________________________________________
# training:
# RandomForestClassifier(bootstrap=True, compute_importances=False,
#             criterion=gini, max_depth=None, max_features=auto,
#             min_density=0.1, min_samples_leaf=1, min_samples_split=1,
#             n_estimators=60, n_jobs=-1, oob_score=False, random_state=None,
#             verbose=0)
# training time: 107.65
# test time: 2.78
# confusion matrix:
# [[1883   71]
#  [ 398  295]]
# classification rate:
# 82.2818284851 %
# AUC for test:  0.85516519191
# ROC plot

# %%
## test ensemble extremely randomized tree
random_forest_classifier = ensemble.ExtraTreesClassifier(n_estimators = 100, n_jobs = -1)
train_X_sparse, test_X_sparse = train_X, test_X
train_X, test_X = train_X.todense(), test_X.todense()
misclassified = benchmark(random_forest_classifier)
train_X, test_X = train_X_sparse, test_X_sparse
# Out:
# ____________________________________________________________________________
# training:
# ExtraTreesClassifier(bootstrap=False, compute_importances=False,
#            criterion=gini, max_depth=None, max_features=auto,
#            min_density=0.1, min_samples_leaf=1, min_samples_split=1,
#            n_estimators=100, n_jobs=-1, oob_score=False, random_state=None,
#            verbose=0)
# training time: 150.70
# test time: 3.42
# confusion matrix:
# [[1884   70]
#  [ 404  289]]
# classification rate:
# 82.0929353986 %
# AUC for test:  0.857511361606
# ROC plot

# %%
## test ensemble GradientBoostingClassifier
boosting_classifier = ensemble.GradientBoostingClassifier(n_estimators = 200, max_depth = 1, learn_rate = 0.1)
train_X_sparse, test_X_sparse = train_X, test_X
train_X, test_X = train_X.todense(), test_X.todense()
misclassified = benchmark(boosting_classifier)
train_X, test_X = train_X_sparse, test_X_sparse
# Out:
# ____________________________________________________________________________
# training:
# GradientBoostingClassifier(init=None, learn_rate=0.1, loss=deviance,
#               max_depth=1, max_features=None, min_samples_leaf=1,
#               min_samples_split=1, n_estimators=100,
#               random_state=<mtrand.RandomState object at 0x1049c32e8>,
#               subsample=1.0)
# training time: 57.14
# test time: 0.08
# confusion matrix:
# [[1816  138]
#  [ 356  337]]
# classification rate:
# 81.3373630525 %
# AUC for test:  0.835463495904
# ROC plot

# %%
## test ridge classifier
ridge_classifier = linear_model.RidgeClassifier(tol = 1e-1)
benchmark(ridge_classifier)
# Out:
# ____________________________________________________________________________
# training:
# RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
#         normalize=False, tol=0.1)
# training time: 1.41
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-102-47983bd8e7c1> in <module>()
#       1 ## test ridge classifier
#       2 ridge_classifier = linear_model.RidgeClassifier(tol = 1e-1)
# ----> 3 benchmark(ridge_classifier)
#
# <ipython-input-101-aa6933491c1e> in benchmark(clf)
#      20
#      21     print 'confusion matrix:'
# ---> 22     print metrics.confusion_matrix(test_y, pred)
#      23
#      24     print 'classification rate:'
#
# AttributeError: 'module' object has no attribute 'confusion_matrix'
# test time: 0.00
# confusion matrix:

# %%
## test linear SVC
linear_svc_classifier = svm.LinearSVC(loss = 'l2', penalty = 'l1', dual = False, tol = 1e-3)
benchmark(linear_svc_classifier)

# %%
## do a grid search on meta-pararmeters of SVC
cv_svc_classifier = grid_search.GridSearchCV(svm.SVC(probability = True), 
       dict(
                kernel = ('rbf','linear'),
                C = (1, 10, 100, 1000),
                gamma = (0.01, 0.1, 1),
        ), 
        n_jobs = -1
)
cv_svc_classifier.fit(train_X, train_y)
print cv_svc_classifier.best_estimator_
## SVC(C=10, cache_size=200, class_weight=None, coef0=0.0, degree=3, gamma=0.1,
##  kernel=rbf, probability=False, shrinking=True, tol=0.001, verbose=False)
misclassified = benchmark(cv_svc_classifier.best_estimator_)
# Out:
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0, degree=3, gamma=0.01,
#   kernel=linear, probability=True, shrinking=True, tol=0.001,
#   verbose=False)
# ____________________________________________________________________________
# training:
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0, degree=3, gamma=0.01,
#   kernel=linear, probability=True, shrinking=True, tol=0.001,
#   verbose=False)
# training time: 18.66
# test time: 4.35
# confusion matrix:
# [[1861   93]
#  [ 297  396]]
# classification rate:
# 85.266339252 %
# AUC for test:  0.884823524025
# ROC plot
# [(array([u'1',
#        u"To engage in an intelligent debate with you is like debating to a retarded person.  It's useless.  It looks like you're bent on disregarding the efforts of the government."],
#       dtype='<U13166'),
#   1),
#  (array([u'1', u'GO SUCK_YOU DADDYS_COCK_OBAMA LOVING LIBERAL_FAGGOT'],
#       dtype='<U13166'),
#   1),
#  (array([u'0', u'Would probably be cheaper just to legally change your name.'],
#       dtype='<U13166'),
#   0),
#  (array([u'0',
#        u"r_  Just can't stand the truth can you?  Either that or you are truly enjoying your blissful ignorance!"],
#       dtype='<U13166'),
#   0),
#  (array([u'0', u'Start with impeaching this dumb ass usurper'],
#       dtype='<U13166'),
#   0),
#  (array([u'1',
#        u'stretch her ass open mah nigguh spit in her asshole and put ya dick deep in it give her an ANAL INFECTION BRUH!!!'],
#       dtype='<U13166'),
#   1),
#  (array([u'0',
#        u'Wrong place wrong time and a black man saved him so shut the fuck up'],
#       dtype='<U13166'),
#   0),
#  (array([u'1',
#        u"I'm sure she looks better than the sloppy out of shape bitch you call your girl."],
#       dtype='<U13166'),
#   1),
#  (array([u'0',
#        u
"],
#       dtype='<U13166'),
#   1),
#  (array([u'1', u"You're about as useful as a used tampon, but not as smart."],
#       dtype='<U13166'),
#   1),
#  (array([u'0', u'morons like you do'],
#       dtype='<U13166'), 0),
#  (array([u'1',
#        u'I think this bitch needs to get a checkup by her doctor real fucking soon because she opened her asshole with no effort'],
#       dtype='<U13166'),
#   1),
#  (array([u'1',
#        u"Go study up on econ 101 and get back to us when you know what the H#LL you're talking about"],
#       dtype='<U13166'),
#   1),
#  (array([u'1',
#        u'I thinks you sounds lika real stoopid mofo, iffen I was to sees you hangin ona corner I would be wantin to hurt you real bad.'],
#       dtype='<U13166'),
#   1),
#  (array([u'1', u"Isn't it fun to try and cover up evil, you bastard!"],
#       dtype='<U13166'),
#   1),
#  (array([u'1',
#        u"How is being anti-pedophile and supporting the right of a parent to defend their child out of touch with the majority of the world?  I think maybe your circle of friends are all pedos and it's you who is out of touch.  Get some non-pedo friends and you'll see."],
#       dtype='<U13166'),
#   1),
#  (array([u'1',
#        u'The easy part about Walker pissing me off is he arbitrily takes away a bargained for right. Then sits back while people like you, who know nothing about unions, do his dirty work for him. Why  enjoy being a pawn?'],
#       dtype='<U13166'),
#   1),
#  (array([u'1',
#        u'Another inferior leftist with no substance. Is that all you got?...."the car thief?"....sure sign you\'re losing. But then again inferior, leftists like you never address the facts of the issue....that\'s why you\'re inferior.'],
#       dtype='<U13166'),
#   1),
#  (array([u'1',
#        u'Is that why Obama has borrowed more money as president in 3 years than any other sitting president in US history?  You are delusional.'],
#       dtype='<U13166'),
#   1),
#  (array([u'1',
#        u"Didn't condem that did you? But yet you cry like a girl because your master was interrupted.  Loser"],
#       dtype='<U13166'),
#   1),
#  (array([u'0', u"who's this ugly bitch?"],
#       dtype='<U13166'), 0),
#  (array([u'0',
#        u'what a nerd. you would get your ass kicked by a black guy if you used that word in front of him. '],
#       dtype='<U13166'),
#   0),
#  (array([u'1',
#        u"and I thought Dem's put up their presidential kneepad after Clinton left town.......  Guess not....so tell us.....u spit or swallow?"],
#       dtype='<U13166'),
#   1),
#  (array([u'1',
#        u'@Fuck:disqus you CNN. Censor my @ass:disqus a little more, please.'],
#       dtype='<U13166'),
#   1),
#  (array([u'1',
#        u"He didn't do anything to take away guns, even from buffoons like you!"],
#       dtype='<U13166'),
#   1),
#  (array([u'1',
#        u'Go back to your nerd table. Better yet, a shallow ditch would suit you fine'],
#       dtype='<U13166'),
#   1),
#  (array([u'0',
#        u"Dennis keeps deflecting on that IRS data. LMAO   listen to this baloney                   Its not the IRS idiot.  and I am not going to do your homework for you.  Someone here mentioned a poll and I went..all on my own and did a search on the topic and found all kinds of info   you need to do the same....I have no interest in spoon feeding you like you're used to"],
#       dtype='<U13166'),
#   0),
#  (array([u'1',
#        u'You are a poor excuse for a human and one of the reasons our country is going down the toilet!!!!!'],
#       dtype='<U13166'),
#   1),
#  (array([u'1',
#        u'I\'m so tired of some people cramming their religion into other people\'s faces and being so noisy about it. I thought you were supposed to pray in closets. The first commandment should have been "Don\'t be a dick."'],
#       dtype='<U13166'),
#   1),
#  (array([u'1',
#        u'No, people have a right to speak, no matter how stupid they are.'],
#       dtype='<U13166'),
#   1),
#  (array([u'0',
#        u"I bet you will find that the Free Syrian Army is killing women and children too. You are a fool if you don't understand this about these terrorists."],
#       dtype='<U13166'),
#   0),
#  (array([u'1',
#        u"kingfisher192 ...........come on, name the lies!\xc2  You tool, you never even heard the man's words.\xc2  You are just doing what little abused trolls do.....follow orders.........good little slave trollbitch!"],
#       dtype='<U13166'),
#   1),
#  (array([u'1',
#        u"Go use google simpleton, that's how the word is spelled.  You dense democrat!"],
#       dtype='<U13166'),
#   1),
#  (array([u'1',
#        u"Obviously the comic books you read have done you no good. I bet if your keyboard looked like crayons you'd almost sound intaligent."],
#       dtype='<U13166'),
#   1)]

# %%
## test naive bayesian multinomial
nb_multinomial_classifier = naive_bayes.MultinomialNB(alpha = 0.4)
misclassified = benchmark(nb_multinomial_classifier)
# Out:
# ____________________________________________________________________________
# training:
# MultinomialNB(alpha=0.4, fit_prior=True)
# training time: 0.01
# test time: 0.00
# confusion matrix:
# [[1923   31]
#  [ 468  225]]
# classification rate:
# 81.148469966 %
# AUC for test:  0.855968664566
# ROC plot
